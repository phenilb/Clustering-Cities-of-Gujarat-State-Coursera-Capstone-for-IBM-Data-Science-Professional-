# %%
from bs4 import BeautifulSoup
import requests

# %%
website_html = requests.get('https://en.wikipedia.org/wiki/List_of_districts_of_Gujarat').text

# %%
soup = BeautifulSoup(website_html, 'lxml')

# %%
import pandas as pd
mylist = []
for tr in soup.find_all('tr')[1:]:
    tds = tr.find_all('td')
    try:
        mylist.append([tds[0].text.rstrip(), tds[1].text.rstrip(), tds[2].text.rstrip(),\
                       tds[3].text.rstrip(), tds[4].text.rstrip(), tds[5].text.rstrip(),\
                       tds[6].text.rstrip(), tds[7].text.rstrip(), tds[8].text.rstrip(), tds[9].text.rstrip()])    
    except:
        next
df = pd.DataFrame(mylist, columns=['No.', 'District', 'Capital', \
                                   'Population 2001 Census', 'Population 2011 Census', 'Area', \
                                   'Density 2011', 'Year of Formation', 'Taluka', 'Total Talukas'])

df.head(15)
# Out:
#    No.          District         Capital Population 2001 Census  \
# 0    1         Ahmedabad       Ahmedabad              5,673,090
# 1    2            Amreli          Amreli              1,393,880
# 2    3             Anand           Anand              1,856,712
# 3    4          Aravalli          Modasa                908,797
# 4    5       Banaskantha        Palanpur              2,502,843
# 5    6           Bharuch         Bharuch              1,370,104
# 6    7         Bhavnagar       Bhavnagar              2,065,492
# 7    8             Botad           Botad                547,567
# 8    9    Chhota Udaipur  Chhota Udaipur                909,799
# 9   10             Dahod           Dahod              1,635,374
# 10  11              Dang            Ahwa                186,712
# 11  12  Devbhoomi Dwarka      Khambhalia                623,091
# 12  13       Gandhinagar     Gandhinagar              1,334,731
# 13  14       Gir Somnath         Veraval              1,059,675
# ...

# %%
df.drop(['No.', 'District', 'Population 2001 Census', 'Area', 'Year of Formation', 'Taluka'], axis=1, inplace=True)
df.head(7)
# Out:
#      Capital Population 2011 Census Density 2011 Total Talukas
# 0  Ahmedabad              7,045,313          983            10
# 1     Amreli              1,513,614          224            11
# 2      Anand              2,090,276          446             8
# 3     Modasa              1,039,918          323             6
# 4   Palanpur              3,116,045          245            14
# 5    Bharuch              1,550,822          238             9
# 6  Bhavnagar              2,393,272          287            10

# %%
df
# Out:
#            Capital Population 2011 Census Density 2011 Total Talukas
# 0        Ahmedabad              7,045,313          983            10
# 1           Amreli              1,513,614          224            11
# 2            Anand              2,090,276          446             8
# 3           Modasa              1,039,918          323             6
# 4         Palanpur              3,116,045          245            14
# 5          Bharuch              1,550,822          238             9
# 6        Bhavnagar              2,393,272          287            10
# 7            Botad                656,005          256             4
# 8   Chhota Udaipur              1,071,831          331             6
# 9            Dahod              2,126,558          583             9
# 10            Ahwa                226,769          129             3
# 11      Khambhalia                752,484          132             4
# 12     Gandhinagar              1,387,478          641             4
# ...

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Ahmedabad, Gujarat, India'

geolocator = Nominatim(user_agent="gujarat_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Ahmedabad are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Ahmedabad are 23.0216238, 72.5797068.

# %%
#!conda install -c conda-forge geocoder --yes 

import geocoder # import geocoder

lat_lng_coords = None

# loop until you get the coordinates
for city in df['Capital']:
    print(city)
# Out:
# Ahmedabad
# Amreli
# Anand
# Modasa
# Palanpur
# Bharuch
# Bhavnagar
# Botad
# Chhota Udaipur
# Dahod
# Ahwa
# Khambhalia
# Gandhinagar
# Veraval
# Jamnagar
# Junagadh
# Bhuj
# Nadiad
# Lunavada
# Mehsana
# Morbi
# Rajpipla
# Navsari
# Godhra
# Patan
# Porbandar
# Rajkot
# Himmatnagar
# Surat
# Surendranagar
# Vyara
# Vadodara
# Valsad

# %%
newlist = []
from  geopy.geocoders import Nominatim
geolocator = Nominatim()

for city in df['Capital']:
    try:
        loc = geolocator.geocode(city+', Gujarat, India')
        newlist.append([city, loc.latitude, loc.longitude])
    except:
        next

newdf = pd.DataFrame(newlist, columns=['City', 'Latitude', 'Longitude'])

newdf
# Out:
#               City   Latitude  Longitude
# 0        Ahmedabad  23.021624  72.579707
# 1           Amreli  20.866667  70.750000
# 2            Anand  22.558499  72.962563
# 3           Modasa  23.463424  73.299063
# 4         Palanpur  24.170979  72.436638
# 5          Bharuch  21.750000  73.000000
# 6        Bhavnagar  21.771884  72.141645
# 7            Botad  22.168600  71.668500
# 8   Chhota Udaipur  22.304865  74.012611
# 9            Dahod  22.835854  74.255678
# 10            Ahwa  20.758726  73.687353
# 11      Khambhalia  22.460833  70.070869
# 12     Gandhinagar  23.223288  72.649227
# 13         Veraval  20.905700  70.378100
# 14        Jamnagar  22.250000  70.000000
# 15        Junagadh  21.250000  70.333333
# 16            Bhuj  23.247245  69.668339
# 17          Nadiad  22.689507  72.871520
# 18        Lunavada  23.129171  73.610956
# 19         Mehsana  23.601263  72.374152
# 20           Morbi  22.817666  70.834593
# 21        Rajpipla  21.869745  73.504813
# ...

# %%
#!conda install -c conda-forge googlemaps --yes 
import googlemaps

# %%
df.to_pickle("citiesofgujarat.pickle")
newdf.to_pickle("gujcitieslocation.pickle")

# %%
gmaps_key = googlemaps.Client(key = "AIzaSyB9ivRzIKZ2cy-wSqbmtnGk3E27kSXIXxM")
nlist = []

for city in df['Capital']:
    ncity = city + ', Gujarat, India'
    try:
        geocode_result = gmaps_key.geocode(ncity)
        lat = geocode_result[0]['geometry']['location']['lat']
        lng = geocode_result[0]['geometry']['location']['lng']
        nlist.append([city, lat, lng])
    except:
        next

ndf = pd.DataFrame(nlist, columns=['City', 'Latitude', 'Longitude'])

ndf
